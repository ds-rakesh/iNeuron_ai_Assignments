# %%
for i in range(1,6):
    print(i*"*")
for i in range(4,0,-1):
    print(i*"*")
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
word = input("Enter ineuron: ")
print(word[::-1])
# Out:
# Enter ineuron: ineuron
# norueni
